# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets
from sklearn.decomposition import PCA

import numpy as np
import pandas as pd

import matplotlib as plt
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

import nltk
import seaborn as sns
from nltk.corpus import stopwords

# %%
df=pd.read_csv('Новая выгрузка обр.csv', encoding="cp1251")
df
# Out:
#                   Автор                                Место работы автора  \
# 0         Антонова С.В.                                     АО «Интерфакс»
# 1        Картошкин С.А.      Министерство просвещения Российской Федерации
# 2          Цивилев С.Е.                  Администрация Кемеровской области
# 3           Волков Г.А.       Министерство транспорта Российской Федерации
# 4           Атанов И.В.  Ставропольский государственный аграрный универ...
# ...                 ...                                                ...
# 4887    Запруднова Е.В.                 Администрация Владимирской области
# 4888  Черноскутова И.А.  Министерство образования и науки Российской Фе...
# 4889      Медведев Д.А.         Аппарат Правительства Российской Федерации
# 4890      Синюгина Т.Ю.  Министерство образования и науки РФ. Заместите...
# 4891         Асаул Н.А.       Министерство транспорта Российской Федерации
#
#           Адресат     Специализация адресата  \
# ...

# %%
df['Количество слов'] = df['Содержание'].apply(lambda x: len(str(x).split(' ')))

# %%
df['Популярные слова'] = 'xxx'
df
# Out:
#                   Автор                                Место работы автора  \
# 0         Антонова С.В.                                     АО «Интерфакс»
# 1        Картошкин С.А.      Министерство просвещения Российской Федерации
# 2          Цивилев С.Е.                  Администрация Кемеровской области
# 3           Волков Г.А.       Министерство транспорта Российской Федерации
# 4           Атанов И.В.  Ставропольский государственный аграрный универ...
# ...                 ...                                                ...
# 4887    Запруднова Е.В.                 Администрация Владимирской области
# 4888  Черноскутова И.А.  Министерство образования и науки Российской Фе...
# 4889      Медведев Д.А.         Аппарат Правительства Российской Федерации
# 4890      Синюгина Т.Ю.  Министерство образования и науки РФ. Заместите...
# 4891         Асаул Н.А.       Министерство транспорта Российской Федерации
#
#           Адресат     Специализация адресата  \
# ...

# %%
df['Специализация адресата'].value_counts()
# Out:
# Специалист по региональным чемпионатам    1542
# Генеральный директор                      1451
# Административный директор                  723
# Вопросы повышения квалификации             307
# Вузовские чемпионаты                       232
# Сертификация экспертов WS                  226
# Новые компитненции                         129
# Вопросы аккредитации                       115
# Поздравления                                78
# Реклама и сотрудничество                    60
# WS Europe                                   17
# Участие в выставках                         12
# Name: Специализация адресата, dtype: int64

# %%
df[df['Специализация адресата'].str.contains("Специалист по региональным чемпионатам")]
# Out:
#                   Автор                                Место работы автора  \
# 15        Бойченко С.А.                       Департамент образования ЯНАО
# 16         Храпова Л.А.  Департамент образования, культуры и спорта Нен...
# 18         Борисов Д.В.  Департамент Смоленской области по образованию ...
# 19        Воронков А.Г.        Министерство образования Пензенской области
# 20       Запруднова Е.В       Департамент образования Владимирской области
# ...                 ...                                                ...
# 4832   Горностаева И.В.  Министерство образования и молодежной политики...
# 4833       Осташко О.А.          Министерство образования Тульской области
# 4869        Силинг А.Л.  Агентство стратегических инициатив по продвиже...
# 4873  Александрова М.В.  Региональный институт профессионального развит...
# 4875      Забайкин Г.М.  Департамент образования и молодежной политики ...
#
#           Адресат                  Специализация адресата  \
# ...

# %%
y = pd.Series(' '.join(df[df['Специализация адресата'].str.contains("Специалист по региональным чемпионатам")]['Содержание']).lower().split()).value_counts()[:3]
y
# Out:
# участ        629
# проведен     513
# чемпионат    361
# dtype: int64

# %%
df.loc[(df['Специализация адресата'] == 'Специалист по региональным чемпионатам'), 'Популярные слова'] = 'участ проведен чемпионат'
df
# Out:
#                   Автор                                Место работы автора  \
# 0         Антонова С.В.                                     АО «Интерфакс»
# 1        Картошкин С.А.      Министерство просвещения Российской Федерации
# 2          Цивилев С.Е.                  Администрация Кемеровской области
# 3           Волков Г.А.       Министерство транспорта Российской Федерации
# 4           Атанов И.В.  Ставропольский государственный аграрный универ...
# ...                 ...                                                ...
# 4887    Запруднова Е.В.                 Администрация Владимирской области
# 4888  Черноскутова И.А.  Министерство образования и науки Российской Фе...
# 4889      Медведев Д.А.         Аппарат Правительства Российской Федерации
# 4890      Синюгина Т.Ю.  Министерство образования и науки РФ. Заместите...
# 4891         Асаул Н.А.       Министерство транспорта Российской Федерации
#
#           Адресат     Специализация адресата  \
# ...

# %%
df[df['Специализация адресата'].str.contains("Специалист по региональным чемпионатам")]
# Out:
#                   Автор                                Место работы автора  \
# 15        Бойченко С.А.                       Департамент образования ЯНАО
# 16         Храпова Л.А.  Департамент образования, культуры и спорта Нен...
# 18         Борисов Д.В.  Департамент Смоленской области по образованию ...
# 19        Воронков А.Г.        Министерство образования Пензенской области
# 20       Запруднова Е.В       Департамент образования Владимирской области
# ...                 ...                                                ...
# 4832   Горностаева И.В.  Министерство образования и молодежной политики...
# 4833       Осташко О.А.          Министерство образования Тульской области
# 4869        Силинг А.Л.  Агентство стратегических инициатив по продвиже...
# 4873  Александрова М.В.  Региональный институт профессионального развит...
# 4875      Забайкин Г.М.  Департамент образования и молодежной политики ...
#
#           Адресат                  Специализация адресата  \
# ...
